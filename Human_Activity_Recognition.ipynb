# %% [markdown]
# <a href="https://colab.research.google.com/github/rishika-saha/ML-Projects/blob/main/Human_Activity_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Importing Dataset Directly From Kaggle-https://www.kaggle.com/uciml/human-activity-recognition-with-smartphones***

# %%
# !pip install kaggle
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download uciml/human-activity-recognition-with-smartphones

# %%
# !unzip /content/human-activity-recognition-with-smartphones.zip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_set = pd.read_csv('/content/train.csv')
test_set = pd.read_csv('/content/test.csv')

# %%
train_set.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  ...  subject  Activity
# 0           0.288585          -0.020294  ...        1  STANDING
# 1           0.278419          -0.016411  ...        1  STANDING
# 2           0.279653          -0.019467  ...        1  STANDING
# 3           0.279174          -0.026201  ...        1  STANDING
# 4           0.276629          -0.016570  ...        1  STANDING
#
# [5 rows x 563 columns]

# %%
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Columns: 563 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), int64(1), object(1)
# memory usage: 31.6+ MB

# %%
test_set.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  ...  subject  Activity
# 0           0.257178          -0.023285  ...        2  STANDING
# 1           0.286027          -0.013163  ...        2  STANDING
# 2           0.275485          -0.026050  ...        2  STANDING
# 3           0.270298          -0.032614  ...        2  STANDING
# 4           0.274833          -0.027848  ...        2  STANDING
#
# [5 rows x 563 columns]

# %%
test_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2947 entries, 0 to 2946
# Columns: 563 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), int64(1), object(1)
# memory usage: 12.7+ MB

# %% [markdown]
# **Preprocessing dataset**

# %%
from sklearn.utils import shuffle
train_set = shuffle(train_set)

# %%
x_train = train_set.iloc[:, :-2].values
y_train = train_set.iloc[:, -1].values

# %%
x_test = test_set.iloc[:,:-2].values
y_test = test_set.iloc[:,-1].values

# %%
x_train.shape, y_train.shape
# Out:
# ((7352, 561), (7352,))

# %%
x_test.shape, y_test.shape
# Out:
# ((2947, 561), (2947,))

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.transform(y_test)

# %% [markdown]
# **Dimensionality Reduction**

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=350)
x_train=pca.fit_transform(x_train)
x_test=pca.transform(x_test)

# %% [markdown]
# **Model**

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'rbf',random_state=0)
classifier.fit(x_train,y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=0, shrinking=True, tol=0.001,
#     verbose=False)

# %% [markdown]
# **Accuracy Score**

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred = classifier.predict(x_test)
accuracy_score(y_test,y_pred1)
# Out:
# 0.9562266711910418
